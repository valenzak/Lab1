# %%
#Allow Canopy and ArcPy to import each others' packages
import sys
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.2\\bin')
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.2\\arcpy')
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.2\\ArcToolbox\\Scripts')

# %% [markdown]
# 1) Join the table to the shapefile, which adds county names to each census tract.  At first, I was going to write out about 50 elifs, but I asked Prof. Bergmann, who recommended a join would be more efficient (Duh).  I got halfway through writing my elifs, so this step, along with the initial setup of everything, took half an hour or so. Less than 10 minutes after Bergmann recommended joining.

# %%
##Join county names to census tracts via FIPS and FP fields

#import environments
import arcpy
from arcpy import env
arcpy.env.workspace = "C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test" #Direct to the workspace folder

#define in dataset - the one to be modified
in_data = "saep_bg10.shp"
#define in field
in_field = "COUNTYFP10"
#define table to join to the in dataset
join_table = "WashingtonFIPS.dbf"
#define field with values that correlate with those on the in field
join_field = "FIPSCounty"

#execute join
arcpy.JoinField_management(in_data, in_field, join_table, join_field)
# Out:
# <Result 'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\saep_bg10.shp'>

# %% [markdown]
# 2) I found the proper tool, Statistics_analysis, fairly quickly, but I could not get the syntax right for the life of me.  Heaven forbid there aren't two [[]] around "POP2013", "SUM"...  Anyways, by looking for examples online, I noticed that all of them did this. This problem solving took half an hour, tops.

# %%
##Sum POP2013 for each CountyName into a new table called top10

#import environments
import arcpy
from arcpy import env
arcpy.env.workspace = "C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test"

#define in table
in_table = "saep_bg10.shp"
#define out table and file location
out_table = "C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyPops.dbf"
#define field with values -1- to undergo the statistics operation -2-
statistics_field = [["POP2013", "SUM"]]
#define a field for which to group like values for the statistical operation on the statistics_field
case_field = ["CountyName"]

#execute statistics analysis
List = arcpy.Statistics_analysis(in_table, out_table, statistics_field, case_field)

# %% [markdown]
# 3) Split the original saep_bg10 into many shape files, based on county name.  I started by finding the Split tool in the toolbox, and making sure it was the right tool.  I then typed arcpy.split, and was able to pick the right tool from the autocorrect.  This did not take a long time; I basically just double-checked what the split tool did, and then applied it.  It worked the first time.

# %%
##Split saep_bg10 into seperate shapefiles for each county name

#Import environments
import arcpy
from arcpy import env
arcpy.env.workspace = "C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test"

#Define input dataset to be split
in_feature = "saep_bg10.shp"
#Define dataset to do the splitting
split_feature = "saep_bg10.shp"
#Define field with actual split values
split_field = "CountyName"
#Define the folder to send the results of the splits
out_workspace = "C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps"

#Execute split
arcpy.Split_analysis(in_feature, split_feature, split_field, out_workspace)
# Out:
# <Result 'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps'>

# %% [markdown]
# 4) Sort the counties by their populations, descending order.  I started by typing arcpy.sort into the Python interface in ArcGIS, and was able to select the right tool based on my expectations.  I don't remember this part of the code giving me any trouble, though  I'm not sure how long this one took me because I also went back and decompressed all the older pieces of code by adding definitions and notes to the reader.  Until this, the entire code was about 6 or 7 lines long total.  I think I worked about an hour and a half on getting everything just the way I wanted it, as well as writing this part of the code

# %%
##Sort the counties by their populations, descending, in a new table

#Import environments
import arcpy
from arcpy import env
arcpy.env.workspace = "C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test"

#Define input
in_dataset = "CountyPops.dbf"
#Define output file
out_dataset = "C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyPopsSort.dbf"
#Define which column to sort by, and in what order
sort_field = [["SUM_POP201", "DESCENDING"]]

#Execute the sort
arcpy.Sort_management(in_dataset, out_dataset, sort_field)
# Out:
# <Result 'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyPopsSort.dbf'>

# %% [markdown]
# 5) Print the top ten county populations based on the pre-sorted table. I read most of the code out of the book, but struggled at getting only the top ten to print for quite a while.  I tried to use where loops (i = 0...i +=1) and for loops (for OBJECTID* <= 10), and a good amount of other nonsense I can't quite remember.  I might have worked through a whole bunch of this nonsense for over 45 minutes.  I took a break, came back, noticed the where_clause, and had my code finished with comments, variables, and all within 10 minutes after my break.

# %%
##Print top 10 counties by population based on the pre-sorted table from step 4
#I've included county names, just to be fancy

#import environments
import arcpy
from arcpy import env
arcpy.env.workspace = "C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test"

#Define table containing pre-sorted populations
in_table = "CountyPopsSort.dbf"
#Define field names to be listed
field_names = ["SUM_POP201", "CountyName"]
#Define paramater where only the first ten are printed
where = '"OID" < 10'

#Define cursor span using the variables above
cursor = arcpy.da.SearchCursor(in_table, field_names, where)

#Execute the print
for row in cursor:
     print "{0}".format(row[0:2])
# Out:
# (1981900.0, u'King')
# (814500.0, u'Pierce')
# (730500.0, u'Snohomish')
# (480000.0, u'Spokane')
# (435500.0, u'Clark')
# (260100.0, u'Thurston')
# (254000.0, u'Kitsap')
# (247250.0, u'Yakima')
# (205800.0, u'Whatcom')
# (183400.0, u'Benton')

# %% [markdown]
# 6) Set up the environment variables for GDAL/OGR.  Following the directions on the assignment prompt...

# %%
##Set up the environment variables for GDAL/OGR

from subprocess import call
import os

os.environ["GDAL_DATA"] = "C:\\OSGeo4W\\share\\gdal"
os.environ["GDAL_DRIVER_PATH"] = "C:\\OSGeo4W\\bin\\gdalplugins"
os.environ["PROJ_LIB"] = "C:\\OSGeo4W\\share\\proj"
os.environ["PATH"] = "C:\\OSGeo4W\\bin;"+os.environ["PATH"]+";C:\\OSGeo4W\\apps\\msys\\bin;C:\\OSGeo4W\\apps\\Python27\\Scripts"

# %%
##Execute conversion of county shapefiles with GDAL/OGR

call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Adams.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Adams.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Asotin.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Asotin.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Benton.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Benton.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Chelan.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Chelan.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Clallam.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Clallam.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Clark.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Clark.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Columbia.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Columbia.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Cowlitz.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Cowlitz.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Douglas.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Douglas.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Ferry.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Ferry.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Franklin.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Franklin.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Garfield.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Garfield.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Grant.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Grant.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Grays Harbor.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Grays Harbor.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Island.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Island.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Jefferson.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Jefferson.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\King.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\King.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Kitsap.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Kitsap.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Kittitas.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Kittitas.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Klickitat.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Klickitat.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Lewis.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Lewis.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Lincoln.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Lincoln.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Mason.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Mason.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Okanogan.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Okanogan.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Pacific.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Pacific.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Pend Oreille.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Pend Oreille.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Pierce.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Pierce.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\San Juan.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\San Juan.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Skagit.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Skagit.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Skamania.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Skamania.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Snohomish.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Snohomish.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Spokane.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Spokane.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Stevens.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Stevens.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Thurston.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Thurston.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Wahikiakum.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Wahikiakum.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Walla Walla.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Walla Walla.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Whatcom.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Whatcom.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Whitman.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Whitman.shp'])
call(['C:\\OSGeo4W\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:2927',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyJSONs\\Yakima.geojson',
      'C:\\Users\\valenzak\\Documents\\GitHub\\Lab1\\test\\CountyShps\\Yakima.shp'])
# Out:
# 0
